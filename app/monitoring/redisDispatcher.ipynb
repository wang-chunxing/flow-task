# %%
graph TD
    A[TaskEngine] -->|dispatch| B[RedisDispatcher]
    B --> C[Redis Stream]
    C --> D[Consumer Group]
    D --> E[Log Handler]
    D --> F[Metrics Collector]
    D --> G[Alert Manager]
